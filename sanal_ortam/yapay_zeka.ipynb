# %%
import pandas as pd
data_yolu = '/workspaces/Degerler/winemag-data-130k-v2.csv'
df=pd.read_csv(data_yolu,index_col=0)
df.head(1)
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery
# 0  Nicosia

# %%
description_50 = df['description'].head(50)
print(description_50)
# Out:
# 0     Aromas include tropical fruit, broom, brimston...
# 1     This is ripe and fruity, a wine that is smooth...
# 2     Tart and snappy, the flavors of lime flesh and...
# 3     Pineapple rind, lemon pith and orange blossom ...
# 4     Much like the regular bottling from 2012, this...
# 5     Blackberry and raspberry aromas show a typical...
# 6     Here's a bright, informal red that opens with ...
# 7     This dry and restrained wine offers spice in p...
# 8     Savory dried thyme notes accent sunnier flavor...
# 9     This has great depth of flavor with its fresh ...
# 10    Soft, supple plum envelopes an oaky structure ...
# 11    This is a dry wine, very spicy, with a tight, ...
# 12    Slightly reduced, this wine offers a chalky, t...
# 13    This is dominated by oak and oak-driven aromas...
# 14    Building on 150 years and six generations of w...
# 15    Zesty orange peels and apple notes abound in t...
# 16    Baked plum, molasses, balsamic vinegar and che...
# ...

# %%
df['description'].iloc[:50]
# Out:
# 0     Aromas include tropical fruit, broom, brimston...
# 1     This is ripe and fruity, a wine that is smooth...
# 2     Tart and snappy, the flavors of lime flesh and...
# 3     Pineapple rind, lemon pith and orange blossom ...
# 4     Much like the regular bottling from 2012, this...
# 5     Blackberry and raspberry aromas show a typical...
# 6     Here's a bright, informal red that opens with ...
# 7     This dry and restrained wine offers spice in p...
# 8     Savory dried thyme notes accent sunnier flavor...
# 9     This has great depth of flavor with its fresh ...
# 10    Soft, supple plum envelopes an oaky structure ...
# 11    This is a dry wine, very spicy, with a tight, ...
# 12    Slightly reduced, this wine offers a chalky, t...
# 13    This is dominated by oak and oak-driven aromas...
# 14    Building on 150 years and six generations of w...
# 15    Zesty orange peels and apple notes abound in t...
# 16    Baked plum, molasses, balsamic vinegar and che...
# ...

# %%
df.loc[:50,['description']]
# Out:
#                                           description
# 0   Aromas include tropical fruit, broom, brimston...
# 1   This is ripe and fruity, a wine that is smooth...
# 2   Tart and snappy, the flavors of lime flesh and...
# 3   Pineapple rind, lemon pith and orange blossom ...
# 4   Much like the regular bottling from 2012, this...
# 5   Blackberry and raspberry aromas show a typical...
# 6   Here's a bright, informal red that opens with ...
# 7   This dry and restrained wine offers spice in p...
# 8   Savory dried thyme notes accent sunnier flavor...
# 9   This has great depth of flavor with its fresh ...
# 10  Soft, supple plum envelopes an oaky structure ...
# 11  This is a dry wine, very spicy, with a tight, ...
# 12  Slightly reduced, this wine offers a chalky, t...
# 13  This is dominated by oak and oak-driven aromas...
# 14  Building on 150 years and six generations of w...
# 15  Zesty orange peels and apple notes abound in t...
# ...

# %%
import numpy as np
array = np.array([1,7,9,15,20])
df.iloc[array,0]
# Out:
# 1     Portugal
# 7       France
# 9       France
# 15     Germany
# 20          US
# Name: country, dtype: object

# %%
import numpy as np
array2 = np.array([10,250,375,1234])
df.loc[array2,['price','points']]
# Out:
#       price  points
# 10     19.0      87
# 250    49.0      85
# 375    40.0      88
# 1234   60.0      92

# %% [markdown]
# #Soru
# country sütununun 'Austraila' ve 'New zealand' değerinde olan ve points sütunun 95'e eşit veya yüksek olan değerleri indexleyin. burada isin() methodunu kullanmanız gerekiyor.

# %%
df[(df['country'].isin(['Australia', "New Zealand"])) & (df["points"] >= 95)]
# Out:
#             country                                        description  \
# 345       Australia  This wine contains some material over 100 year...
# 346       Australia  This deep brown wine smells like a damp, mossy...
# 348       Australia  Deep mahogany. Dried fig and black tea on the ...
# 349       Australia  RunRig is always complex, and the 2012 doesn't...
# 356       Australia  Dusty, firm, powerful: just a few apt descript...
# 360       Australia  Bacon and tapenade elements merge easily on th...
# 365       Australia  The Taylor family selected Clare Valley for it...
# 14354     Australia  This wine's concentrated dark fruit shows in t...
# 16538     Australia  Rich, dense and intense, this is a big, muscul...
# 28573     Australia  Astralis has become one of Australia's top col...
# 34502     Australia  This prodigious wine showcases Barossa's abili...
# 34506     Australia  If Standish's Relic is the feminine side of Sh...
# ...

# %% [markdown]
# İçinde italy ve France olmayanları indexleyin

# %%
df_contury=df[~df["country"].isin(["Italy", "France"])]
df_contury.country.unique()
# Out:
# array(['Portugal', 'US', 'Spain', 'Germany', 'Argentina', 'Chile',
#        'Australia', 'Austria', 'South Africa', 'New Zealand', 'Israel',
#        'Hungary', 'Greece', 'Romania', 'Mexico', 'Canada', nan, 'Turkey',
#        'Czech Republic', 'Slovenia', 'Luxembourg', 'Croatia', 'Georgia',
#        'Uruguay', 'England', 'Lebanon', 'Serbia', 'Brazil', 'Moldova',
#        'Morocco', 'Peru', 'India', 'Bulgaria', 'Cyprus', 'Armenia',
#        'Switzerland', 'Bosnia and Herzegovina', 'Ukraine', 'Slovakia',
#        'Macedonia', 'China', 'Egypt'], dtype=object)
